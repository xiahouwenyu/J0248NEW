# %%
import healpy as hp
import mytools as mt
import importlib; importlib.reload(mt)
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Welcome to JupyROOT 6.24/06
# 13:26:23 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=73285;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=978887;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#50\50]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=901776;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=220300;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=883886;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=129176;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
# 13:26:24 INFO      Starting 3ML!                                                                     ]8;id=790083;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=908639;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=791031;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=1980;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=877716;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=47353;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=677216;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=899491;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
# 13:26:25 WARNING   Multinest minimizer not available                                           ]8;id=83271;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=237202;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
# 13:26:27 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=186910;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=960661;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=203460;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=832482;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=342810;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=653418;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 13:26:27 WARNING   No fermitools installed                                              ]8;id=687537;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=371442;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=678732;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=630529;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=301542;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=367547;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %%
map2, skymapHeader = hp.read_map("../data/sigts_J0248.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_J0248_resall.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_res_J0248.fits.gz",h=True)
# map2, skymapHeader = hp.read_map("./llh_skymap/sigts_no_diffuse.fits.gz",h=True)
ra1=42.23
dec1=60.43
mt.hpDraw(map2,ra1,dec1,
      # contours=[], 
      colorlabel="Significance",
      color="Milagro"
    )
# Out:
# 40.14166666666666 61.25694444444444 LS I +61 303
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
# 40.75 60.45 J0243+6027
# 42.07758333333333 60.35963888888889 J0248+6021
# WARNING UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.

# %%
map2 = hp.ma(map2)
hp.mollview(map2)

# %%
from scipy.optimize import curve_fit

def gaussian(x,a,mu,sigma):
    return a*np.exp(-((x-mu)/sigma)**2/2)

bin_y,bin_x,patches=plt.hist(map2.compressed(),bins=100)
plt.close()
bin_x=np.array(bin_x)
bin_y=np.array(bin_y)
fit_range = np.logical_and(bin_x>-5, bin_x<5)
wdt=(bin_x[1]-bin_x[0])/2.
try:
    popt, pcov = curve_fit(
        gaussian,
        bin_x[fit_range] + wdt,
        bin_y[fit_range[:-1]],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
except (ValueError, IndexError):
    popt, pcov = curve_fit(
        gaussian,
        bin_x[:100] + wdt,
        bin_y[:100],
        bounds=([100, -2, 0], [50000000, 2, 10]),
    )
#popt,pcov = curve_fit(gaussian,bin_x[fit_range[0:-1]]+(bin_x[1]-bin_x[0])/2.,bin_y[fit_range[0:-1]],bounds=([100,-2,0],[50000000,2,10]))
print("************************")
print(popt)
print("************************")
print("max Significance= %.1f"%(max(map2.compressed())))

plt.figure()
#plt.plot([0.,0.],[1,1e6],'k--',linewidth=0.5)
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], 0, 1),
    '--',
    label='expectation',
)
plt.plot((bin_x[:100] + bin_x[1:101]) / 2, bin_y, label="data")
plt.plot(
    (bin_x[:100] + bin_x[1:101]) / 2,
    gaussian((bin_x[:100] + bin_x[1:101]) / 2, popt[0], popt[1], popt[2]),
    '--',
    label='fit',
)
plt.yscale('log')
plt.xlim(-10,10)
plt.ylim(1,max(bin_y*2))
plt.grid(True)
plt.text(-9.5,max(bin_y),'mean = %f\n width = %f'%(popt[1],popt[2]))
plt.xlabel(r'Significance($\sigma$)')
plt.ylabel("entries")
plt.legend()
# Out:
# ************************
# [5.24842036e+02 5.04166278e-01 1.07456366e+00]
# ************************
# max Significance= 6.3
