# %%
import matplotlib, sys
# sys.path.append('/home/lhaaso/gmxiang/lib/pip_lib')
import warnings
warnings.simplefilter("ignore")
import numpy as np
np.seterr(all="ignore")
from threeML import *
import os
matplotlib.use('Agg')
#matplotlib.use('Qt5Agg')
#from PyQt5 import QtCore, QtGui, uic
import matplotlib.pyplot as plt
from WCDA_hal import HAL, HealpixConeROI, HealpixMapROI
import ROOT
from time import *
import traceback
import healpy as hp
silence_warnings()
from threeML import silence_progress_bars, activate_progress_bars, toggle_progress_bars
from threeML.utils.progress_bar import trange
# Out:
# Welcome to JupyROOT 6.24/06
# 19:59:15 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=144890;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=192634;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#50\50]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=433749;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=700489;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/functions.py#71\71]8;;\
#                   will not be available.
# 19:59:16 WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=224846;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=908799;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/astromodels/functions/functions_1D/absorption.py#36\36]8;;\
#                   available
# 19:59:17 INFO      Starting 3ML!                                                                     ]8;id=611847;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=941467;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#35\35]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=696748;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=346781;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#36\36]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=948092;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=995499;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#37\37]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=331127;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=87662;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#40\40]8;;\
# 19:59:18 WARNING   Multinest minimizer not available                                           ]8;id=280185;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=492858;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
# 19:59:18 WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=947038;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=792198;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
# 19:59:19 WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=252852;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=438782;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=742037;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=938697;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
# 19:59:19 WARNING   No fermitools installed                                              ]8;id=640602;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=935635;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=961919;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=959973;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=561717;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=941812;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %%
#####   Data Initialize

maptree = "./gcd_new.root"
response = "./WCDA_DR_psf.root"

ra_J0248, dec_J0248 = 42.38, 60.37
ra_LSI61303,dec_LSI61303=40.14166666666666,61.25694444444444
ra1,dec1=ra_J0248,dec_J0248
ra2,dec2=ra_LSI61303,dec_LSI61303


data_radius = 2.5
model_radius = 8.0
roi=HealpixConeROI(ra=ra_J0248,dec=dec_J0248,data_radius=data_radius,model_radius=model_radius)
WCDA = HAL("WCDA", maptree, response, roi, flat_sky_pixels_size=0.17)

#####   Data Situation

# %matplotlib inline
WCDA.set_active_measurements(0, 5)
WCDA.display()

fig = WCDA.display_stacked_image(smoothing_kernel_sigma=0.25)
fig.show()
fig.savefig("sy.png",dpi=300)
# Out:
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 20:01:55 INFO      Creating singleton for                                                            ]8;id=676554;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=12577;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#41\41]8;;\
#                   /Users/shenhuafei/1_Sciencehome/Source/J0248NEW!/WCDA_DR_psf.root
# 20:02:05 INFO      Region of Interest:                                                                   ]8;id=5731;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=207775;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#271\271]8;;\
#          INFO      -------------------                                                                   ]8;id=357641;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=164618;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#272\272]8;;\
#          INFO      HealpixConeROI: Center (R.A., Dec) = (42.380, 60.370), data radius =      ]8;id=740038;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/region_of_interest/healpix_cone_roi.py\healpix_cone_roi.py]8;;\:]8;id=381775;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/region_of_interest/healpix_cone_roi.py#87\87]8;;\
#                   2.500 deg, model radius: 8.000 deg
#          INFO                                                                                            ]8;id=915804;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=862273;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#275\275]8;;\
#          INFO      Flat sky projection:                                                                  ]8;id=24405;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=82958;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#276\276]8;;\
#          INFO      --------------------                                                                  ]8;id=480185;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=221608;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#277\277]8;;\
#          INFO      Width x height: 96 x 96 px                                                            ]8;id=500205;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=44558;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#279\279]8;;\
#          INFO      Pixel sizes: 0.17 deg                                                                 ]8;id=939474;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=607267;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#281\281]8;;\
#          INFO                                                                                            ]8;id=340998;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=643390;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#283\283]8;;\
#          INFO      Response:                                                                             ]8;id=767734;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=639884;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#284\284]8;;\
#          INFO      ---------                                                                             ]8;id=308897;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=937926;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#285\285]8;;\
#          INFO      Response file: /Users/shenhuafei/1_Sciencehome/Source/J0248NEW!/WCDA_DR_psf.root ]8;id=731717;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=183626;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#340\340]8;;\
#          INFO      Number of dec bins: 110                                                          ]8;id=984491;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=929509;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#341\341]8;;\
#          INFO      Number of energy/nHit planes per dec bin_name: 6                                 ]8;id=982582;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=829684;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#344\344]8;;\
#          INFO                                                                                            ]8;id=521332;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=662328;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#289\289]8;;\
#          INFO      Map Tree:                                                                             ]8;id=516555;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=186296;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#290\290]8;;\
#          INFO      ----------                                                                            ]8;id=345260;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=996447;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#291\291]8;;\
#   Bin  Nside Scheme     Obs counts     Bkg counts   obs/bkg  Pixels in ROI  \
# 0   0   1024   RING  965372.068802  962855.320686  1.002614           5990
# 1   1   1024   RING  489604.992802  487964.997482  1.003361           5990
# 2   2   1024   RING   86573.734318   85986.387101  1.006831           5990
# 3   3   1024   RING   36663.935893   36046.974730  1.017115           5990
# 4   4   1024   RING    9293.865310    8996.378328  1.033067           5990
# 5   5   1024   RING    2646.349141    2541.936741  1.041076           5990
#
#    Area (deg^2)
# 0      19.63816
# 1      19.63816
# 2      19.63816
# 3      19.63816
# 4      19.63816
# 5      19.63816
#          INFO      This Map Tree contains 510.000 transits in the first bin                         ]8;id=629616;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py\map_tree.py]8;;\:]8;id=715195;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py#149\149]8;;\
#          INFO      Total data size: 0.58 Mb                                                         ]8;id=60030;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py\map_tree.py]8;;\:]8;id=79566;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py#151\151]8;;\
#          INFO                                                                                            ]8;id=253813;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=102296;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#295\295]8;;\
#          INFO      Active energy/nHit planes (6):                                                        ]8;id=728293;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=329393;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#296\296]8;;\
#          INFO      -------------------------------                                                       ]8;id=838010;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=977581;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#297\297]8;;\
#          INFO      ['0', '1', '2', '3', '4', '5']                                                        ]8;id=206331;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=157446;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#298\298]8;;\
# Error in <TTreeFormula::Compile>:  Bad numerical expression : "name"

# %%
sigma = [0.42, 0.32, 0.25, 0.22, 0.18, 0.15]
for i, data_radius in enumerate(sigma):
    print(i)
    data_radius = 1.501*data_radius
    model_radius = 8.0
    roicache=HealpixConeROI(ra=ra_J0248,dec=dec_J0248,data_radius=data_radius,model_radius=model_radius)
    cache = HAL("WCDA", maptree, response, roicache, flat_sky_pixels_size=0.17)

    #####   Data Situation

    # %matplotlib inline
    cache.set_active_measurements(i, i)
# Out:
# 0
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 1
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 2
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 3
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 4
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 5
# WARNING DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
WCDA._maptree.display()
# Out:
#   Bin  Nside Scheme     Obs counts     Bkg counts   obs/bkg  Pixels in ROI  \
# 0   0   1024   RING  965372.068802  962855.320686  1.002614           5990
# 1   1   1024   RING  489604.992802  487964.997482  1.003361           5990
# 2   2   1024   RING   86573.734318   85986.387101  1.006831           5990
# 3   3   1024   RING   36663.935893   36046.974730  1.017115           5990
# 4   4   1024   RING    9293.865310    8996.378328  1.033067           5990
# 5   5   1024   RING    2646.349141    2541.936741  1.041076           5990
#
#    Area (deg^2)
# 0      19.63816
# 1      19.63816
# 2      19.63816
# 3      19.63816
# 4      19.63816
# 5      19.63816
# 20:40:24 INFO      This Map Tree contains 510.000 transits in the first bin                         ]8;id=49015;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py\map_tree.py]8;;\:]8;id=12825;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py#149\149]8;;\
#          INFO      Total data size: 0.58 Mb                                                         ]8;id=523707;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py\map_tree.py]8;;\:]8;id=282364;file:///Users/shenhuafei/opt/anaconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py#151\151]8;;\

# %%
for bin in range(6):
    # set only one active bin
    WCDA.set_active_measurements(bin, bin)

    fig = WCDA.display_stacked_image(smoothing_kernel_sigma=0.25)
    fig.suptitle("Bin {}".format(bin))
WCDA.display()
# Out:
# 16:55:43 INFO      Region of Interest:                                                                   ]8;id=859467;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=100849;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#271\271]8;;\
#          INFO      -------------------                                                                   ]8;id=479102;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=518147;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#272\272]8;;\
#          INFO      HealpixConeROI: Center (R.A., Dec) = (42.380, 60.370), data radius =      ]8;id=620229;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/region_of_interest/healpix_cone_roi.py\healpix_cone_roi.py]8;;\:]8;id=905688;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/region_of_interest/healpix_cone_roi.py#87\87]8;;\
#                   3.000 deg, model radius: 4.000 deg
#          INFO                                                                                            ]8;id=794803;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=992541;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#275\275]8;;\
#          INFO      Flat sky projection:                                                                  ]8;id=228268;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=889372;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#276\276]8;;\
#          INFO      --------------------                                                                  ]8;id=621273;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=159462;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#277\277]8;;\
#          INFO      Width x height: 48 x 48 px                                                            ]8;id=633075;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=846717;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#279\279]8;;\
#          INFO      Pixel sizes: 0.17 deg                                                                 ]8;id=492579;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=57502;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#281\281]8;;\
#          INFO                                                                                            ]8;id=995913;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=850714;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#283\283]8;;\
#          INFO      Response:                                                                             ]8;id=192284;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=111471;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#284\284]8;;\
#          INFO      ---------                                                                             ]8;id=755776;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=744993;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#285\285]8;;\
#          INFO      Response file:                                                                   ]8;id=121063;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=455105;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#340\340]8;;\
#                   /home/lhaaso/caowy/6_Source/New_Source/J0248+6021/sig_Luo/1/WCDA_DR_psf.root
#          INFO      Number of dec bins: 110                                                          ]8;id=842274;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=30667;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#341\341]8;;\
#          INFO      Number of energy/nHit planes per dec bin_name: 6                                 ]8;id=944053;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py\response.py]8;;\:]8;id=237984;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/response/response.py#344\344]8;;\
#          INFO                                                                                            ]8;id=832007;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=644927;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#289\289]8;;\
#          INFO      Map Tree:                                                                             ]8;id=7002;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=910170;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#290\290]8;;\
#          INFO      ----------                                                                            ]8;id=321049;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=321667;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#291\291]8;;\
#   Bin  Nside Scheme    Obs counts    Bkg counts   obs/bkg  Pixels in ROI  \
# 0   0   1024   RING  1.390742e+06  1.388166e+06  1.001855           8625
# 1   1   1024   RING  7.044770e+05  7.033571e+05  1.001592           8625
# 2   2   1024   RING  1.246908e+05  1.239122e+05  1.006284           8625
# 3   3   1024   RING  5.255174e+04  5.191875e+04  1.012192           8625
# 4   4   1024   RING  1.330570e+04  1.298037e+04  1.025064           8625
# 5   5   1024   RING  3.778259e+03  3.666408e+03  1.030507           8625
#
#    Area (deg^2)
# 0     28.276983
# 1     28.276983
# 2     28.276983
# 3     28.276983
# 4     28.276983
# 5     28.276983
#          INFO      This Map Tree contains 510.000 transits in the first bin                         ]8;id=313717;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py\map_tree.py]8;;\:]8;id=607286;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py#149\149]8;;\
#          INFO      Total data size: 0.83 Mb                                                         ]8;id=95285;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py\map_tree.py]8;;\:]8;id=529017;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/maptree/map_tree.py#151\151]8;;\
#          INFO                                                                                            ]8;id=194323;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=411237;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#295\295]8;;\
#          INFO      Active energy/nHit planes (1):                                                        ]8;id=54630;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=731769;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#296\296]8;;\
#          INFO      -------------------------------                                                       ]8;id=293683;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=264414;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#297\297]8;;\
#          INFO      ['5']                                                                                 ]8;id=793346;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py\HAL.py]8;;\:]8;id=322443;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/HAL.py#298\298]8;;\

# %%
# # A point source with a power law spectrum

# source1_sp = Powerlaw()
# source1 = PointSource("source1", ra=23.5, dec=-22.7, spectral_shape=source1_sp)

# # Another source with a log-parabolic spectrum plus a power law

# source2_sp = Log_parabola() + Powerlaw()
# source2 = PointSource("source2", ra=30.5, dec=-27.1, spectral_shape=source2_sp)

# # A third source defined in terms of its Galactic latitude and longitude
# source3_sp = Cutoff_powerlaw()
# source3 = PointSource("source3", l=216.1, b=-74.56, spectral_shape=source3_sp)

# An extended source with a Gaussian shape centered on R.A., Dec = (3282.5, 0)
# and a sigma of 3.0 degrees
fluxUnit = 1. / (u.TeV * u.cm**2 * u.s)
fitrange=2.5

ext1_spectral = Powerlaw()
# ra1=285.74
# dec1=-0.5
ext1_spatial = Gaussian_on_sphere(lon0=ra1, lat0=dec1, sigma=0.5)
# ext1_spatial = Continuous_injection_diffusion_legacy()

ext1 = ExtendedSource("ext1", spatial_shape=ext1_spatial, spectral_shape=ext1_spectral)

ext1_spectral.K = 1.3e-13 * fluxUnit
ext1_spectral.K.fix=False
ext1_spectral.K.bounds = (1e-14 * fluxUnit, 1e-12*fluxUnit)

ext1_spectral.piv = 3 * u.TeV
ext1_spectral.piv.fix = True

ext1_spectral.index =-2.6
ext1_spectral.index.fix=True
ext1_spectral.index.bounds = (-4., -1.)

ext1_spatial.lon0.bounds=(ra1-fitrange,ra1+fitrange)*u.degree
ext1_spatial.lat0.bounds=(dec1-fitrange,dec1+fitrange)*u.degree

ext1_spatial.sigma.max_value=1*u.degree

pt1_spectral = Powerlaw()

ra2=40.5
dec2=61.25
# ra1=285.74
# dec1=-0.5
# pt1_spatial = Gaussian_on_sphere(lon0=ra1, lat0=dec1, sigma=0.5)
# ext1_spatial = Continuous_injection_diffusion_legacy()

pt1 = PointSource("pt1", ra=ra2, dec=dec2,spectral_shape=pt1_spectral)

pt1_spectral.K = 1.3e-13 * fluxUnit
pt1_spectral.K.fix=False
pt1_spectral.K.bounds = (1e-15 * fluxUnit, 1e-12*fluxUnit)

pt1_spectral.piv = 3 * u.TeV
pt1_spectral.piv.fix = True

pt1_spectral.index =-2.6
pt1_spectral.index.fix=True
pt1_spectral.index.bounds = (-4., -1.)
pt1.position.ra.free=True
pt1.position.dec.free=True

# pt1_spatial.lon0.bounds=(ra1-fitrange,ra1+fitrange)*u.degree
# pt1_spatial.lat0.bounds=(dec1-fitrange,dec1+fitrange)*u.degree

# ext1_spatial.sigma.max_value=1*u.degree

# %%
lm = Model(ext1,pt1) #,bg1

# We can see a summary of the model like this:
lm.display(complete=True)
# Out:
# Model summary:
# ==============
#
#                   N
# Point sources     1
# Extended sources  1
# Particle sources  0
#
# Free parameters (7):
# --------------------
#
#                                value min_value max_value            unit
# ext1.Gaussian_on_sphere.lon0   42.38     39.88     44.88             deg
# ext1.Gaussian_on_sphere.lat0   60.37     57.87     62.87             deg
# ext1.Gaussian_on_sphere.sigma    0.5       0.0       1.0             deg
# ext1.spectrum.main.Powerlaw.K    0.0       0.0       0.0  keV-1 s-1 cm-2
# pt1.position.ra                 40.5       0.0     360.0             deg
# pt1.position.dec               61.25     -90.0      90.0             deg
# pt1.spectrum.main.Powerlaw.K     0.0       0.0       0.0  keV-1 s-1 cm-2
#
# Fixed parameters (4):
# ---------------------
#
#                                           value min_value max_value unit
# ext1.spectrum.main.Powerlaw.piv    3000000000.0      None      None  keV
# ext1.spectrum.main.Powerlaw.index          -2.6      -4.0      -1.0
# pt1.spectrum.main.Powerlaw.piv     3000000000.0      None      None  keV
# pt1.spectrum.main.Powerlaw.index           -2.6      -4.0      -1.0
#
# Properties (0):
# --------------------
#
# (none)
#
#
# Linked parameters (0):
# ----------------------
#
# (none)
#
# Independent variables:
# ----------------------
#
# (none)
#
# Linked functions (0):
# ----------------------
#
# (none)

# %%
time1 = strftime("%m-%d-%H", localtime())
os.system('mkdir ./%s/'%time1)
rllh=[]
result=[]
activate_progress_bars()
# for i in trange(10, desc="progressive"):
#     pass
# for i in trange(13, desc="progressive"):
# i=12
    # try:
    #     ii = str(i)
    #     WCDA.set_active_measurements(i,i)
    #     datalist = DataList(WCDA)
    #     jl = JointLikelihood(lm, datalist, verbose=True)
    #     jl.set_minimizer("minuit")
    #     param_df, like_df = jl.fit()
    #     results=jl.results
    #     fig = WCDA.display_fit(smoothing_kernel_sigma=0.25, display_colorbar=True)
    #     fig.savefig("./%s/fit_result_%i.pdf"%(time1,i))

    #     TS1 = jl.compute_TS("ext1",like_df).values[0][2]
    #     TS2 = jl.compute_TS("ext2",like_df).values[0][2]
    #     TS3 = jl.compute_TS("ext3",like_df).values[0][2]
    #     lll=WCDA.get_log_like()
        
    #     rllh.append([i,TS1,TS2,TS3,lll])
    #     mat=param_df.as_matrix()
    #     result.append([i,mat])
    # except Exception as e:
    #     # rllh.append([])
    #     # result.append([])
    #     pass

# %%
rllh=[]
result=[]
time1 = strftime("%m-%d-%H", localtime())
if not os.path.exists('./%s/'%time1):
    os.system('mkdir ./%s/'%time1)
WCDA.set_active_measurements(1,5)
datalist = DataList(WCDA)
jl = JointLikelihood(lm, datalist, verbose=True)
jl.set_minimizer("minuit")
param_df, like_df = jl.fit()
results=jl.results
fig = WCDA.display_fit(smoothing_kernel_sigma=0.25, display_colorbar=True)
fig.savefig("./%s/fit_result_%i.pdf"%(time1,i))

TS1 = jl.compute_TS("ext1",like_df).values[0][2]
TS2 = jl.compute_TS("pt1",like_df).values[0][2]
# TS3 = jl.compute_TS("ext3",like_df).values[0][2]
lll=WCDA.get_log_like()

rllh.append([i,TS1,TS2,lll])
mat=param_df.values
result.append([i,mat])
# Out:
# 17:23:31 INFO      Considering 7 dec bins for extended source ext1                  ]8;id=908443;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=549991;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#70\70]8;;\
#          INFO      Central bin is bin at Declination = 60.337                       ]8;id=443038;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=813693;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#79\79]8;;\
#          INFO      Considering 7 dec bins for extended source ext1                  ]8;id=428570;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=831365;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#70\70]8;;\
#          INFO      Central bin is bin at Declination = 60.337                       ]8;id=931238;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=3896;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#79\79]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=916211;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=330390;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
#          INFO      set the minimizer to MINUIT                                             ]8;id=350388;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=583375;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1059\1059]8;;\
# 17:23:32 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=108894;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=787565;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.819,60.337,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=152847;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=541210;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.210
#          INFO      trial values: 41.747,60.337,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=865086;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=864019;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.209
#          INFO      trial values: 41.795,60.337,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=985568;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=956651;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.771,60.337,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=616736;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=393974;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.39,0.70088,-21.689,40.423,61.243,-22.471 ->     ]8;id=447882;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=478155;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.264
#          INFO      trial values: 41.783,60.284,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=808949;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=570527;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.266
#          INFO      trial values: 41.783,60.343,0.70088,-21.689,40.423,61.243,-22.471 ->    ]8;id=239777;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=936247;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.33,0.70088,-21.689,40.423,61.243,-22.471 ->     ]8;id=222599;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=748139;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.337,0.70147,-21.689,40.423,61.243,-22.471 ->    ]8;id=746571;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=672709;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.70029,-21.689,40.423,61.243,-22.471 ->    ]8;id=120978;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=597112;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.70466,-21.689,40.423,61.243,-22.471 ->    ]8;id=89389;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=363553;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.337,0.69708,-21.689,40.423,61.243,-22.471 ->    ]8;id=33121;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=701075;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.337,0.70088,-21.67,40.423,61.243,-22.471 ->     ]8;id=223910;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=767092;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.255
#          INFO      trial values: 41.783,60.337,0.70088,-21.708,40.423,61.243,-22.471 ->    ]8;id=717987;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=975284;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.254
#          INFO      trial values: 41.783,60.337,0.70088,-21.687,40.423,61.243,-22.471 ->    ]8;id=382544;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=495870;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.337,0.70088,-21.692,40.423,61.243,-22.471 ->    ]8;id=844060;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=465574;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
# 17:23:33 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.457,61.243,-22.471 ->    ]8;id=203716;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=123162;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.241
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.389,61.243,-22.471 ->    ]8;id=87289;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=309566;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.244
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.428,61.243,-22.471 ->    ]8;id=537265;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=424844;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.204
# 17:23:34 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.418,61.243,-22.471 ->    ]8;id=677286;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=96514;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.204
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.294,-22.471 ->    ]8;id=957751;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=450477;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.552
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.191,-22.471 ->    ]8;id=253760;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=22889;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.438
# 17:23:35 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.248,-22.471 ->    ]8;id=700162;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=443038;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.206
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.237,-22.471 ->    ]8;id=665108;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=601808;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.203
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.246,-22.471 ->    ]8;id=709129;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=346106;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
# 17:23:36 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.239,-22.471 ->    ]8;id=60756;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=236598;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.452 ->    ]8;id=194045;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=812658;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.210
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.49 ->     ]8;id=26302;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=584288;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.209
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.464 ->    ]8;id=954115;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=366339;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.478 ->    ]8;id=717132;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=703391;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.467 ->    ]8;id=152951;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=640611;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.243,-22.475 ->    ]8;id=506822;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=57311;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.239,-22.471 ->    ]8;id=458916;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=68839;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.227,-22.471 ->    ]8;id=816413;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=447045;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.223
#          INFO      trial values: 41.795,60.337,0.70088,-21.689,40.423,61.239,-22.471 ->    ]8;id=842776;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=783988;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.771,60.337,0.70088,-21.689,40.423,61.239,-22.471 ->    ]8;id=900750;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=483056;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.343,0.70088,-21.689,40.423,61.239,-22.471 ->    ]8;id=855581;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=825837;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.33,0.70088,-21.689,40.423,61.239,-22.471 ->     ]8;id=415510;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=71586;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.70466,-21.689,40.423,61.239,-22.471 ->    ]8;id=278395;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=634619;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.69708,-21.689,40.423,61.239,-22.471 ->    ]8;id=2600;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=298183;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.70088,-21.687,40.423,61.239,-22.471 ->    ]8;id=798445;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=758415;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.70088,-21.692,40.423,61.239,-22.471 ->    ]8;id=534523;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=237420;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
# 17:23:37 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.427,61.239,-22.471 ->    ]8;id=82903;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=515872;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.202
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.419,61.239,-22.471 ->    ]8;id=725316;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=386293;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.242,-22.471 ->    ]8;id=799559;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=804101;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
# 17:23:38 INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.237,-22.471 ->    ]8;id=734364;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=931975;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.204
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.239,-22.469 ->    ]8;id=219693;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=89934;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
#          INFO      trial values: 41.783,60.337,0.70088,-21.689,40.423,61.239,-22.473 ->    ]8;id=395342;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=166430;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
#          INFO      trial values: 41.783,60.336,0.70106,-21.689,40.422,61.245,-22.471 ->    ]8;id=392880;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=960826;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=57554;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=227255;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.796,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=99019;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=666288;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.771,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=346212;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=731959;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.343,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=720785;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=375106;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.33,0.70099,-21.689,40.423,61.243,-22.471 ->     ]8;id=310965;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=342210;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70477,-21.689,40.423,61.243,-22.471 ->    ]8;id=260605;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=20566;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.69719,-21.689,40.423,61.243,-22.471 ->    ]8;id=560597;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=435857;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.687,40.423,61.243,-22.471 ->    ]8;id=581510;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=850213;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.692,40.423,61.243,-22.471 ->    ]8;id=252526;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=895616;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
# 17:23:39 INFO      trial values: 41.783,60.337,0.70099,-21.689,40.427,61.243,-22.471 ->    ]8;id=796685;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=399693;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.419,61.243,-22.471 ->    ]8;id=76544;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=871605;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.246,-22.471 ->    ]8;id=835487;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=226962;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
# 17:23:40 INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.24,-22.471 ->     ]8;id=536319;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=462369;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.201
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.245,-22.471 ->    ]8;id=793807;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=221823;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.241,-22.471 ->    ]8;id=632739;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=73126;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.465 ->    ]8;id=958508;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=984519;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.476 ->    ]8;id=236778;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=524539;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=954543;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=889232;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.796,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=846095;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=642018;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.771,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=701904;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=811578;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.343,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=561757;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=326081;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.33,0.70099,-21.689,40.423,61.243,-22.471 ->     ]8;id=262740;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=745851;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70477,-21.689,40.423,61.243,-22.471 ->    ]8;id=745753;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=428013;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.69719,-21.689,40.423,61.243,-22.471 ->    ]8;id=245014;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=698263;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.687,40.423,61.243,-22.471 ->    ]8;id=815835;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=893214;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.692,40.423,61.243,-22.471 ->    ]8;id=801980;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=169492;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.427,61.243,-22.471 ->    ]8;id=586038;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=329388;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.419,61.243,-22.471 ->    ]8;id=1851;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=355887;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.245,-22.471 ->    ]8;id=174594;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=917780;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.241,-22.471 ->    ]8;id=168419;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=970439;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.465 ->    ]8;id=91823;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=764778;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.476 ->    ]8;id=218704;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=563560;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.200
#          INFO      trial values: 41.786,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=844060;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=692000;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.781,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=759599;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=927428;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.338,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=385946;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=145102;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
# 17:23:41 INFO      trial values: 41.783,60.335,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=820582;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=605285;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=893623;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=376879;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.336,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=393271;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=975732;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70175,-21.689,40.423,61.243,-22.471 ->    ]8;id=679901;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=92286;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70023,-21.689,40.423,61.243,-22.471 ->    ]8;id=671290;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=27577;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70114,-21.689,40.423,61.243,-22.471 ->    ]8;id=478232;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=677127;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70084,-21.689,40.423,61.243,-22.471 ->    ]8;id=804169;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=447315;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=525250;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=332808;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.69,40.423,61.243,-22.471 ->     ]8;id=541847;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=534602;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.424,61.243,-22.471 ->    ]8;id=497823;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=907149;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.422,61.243,-22.471 ->    ]8;id=770145;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=398963;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
# 17:23:42 INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=930452;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=477338;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=986242;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=865738;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=801608;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=950508;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.242,-22.471 ->    ]8;id=59324;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=256115;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
# ...
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=823469;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=969203;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.786,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=949605;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=705568;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.786,60.337,0.70114,-21.689,40.423,61.243,-22.471 ->    ]8;id=486825;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=519167;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.786,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=251940;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=853796;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.786,60.337,0.70099,-21.689,40.651,61.243,-22.471 ->    ]8;id=354034;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=854264;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3713.107
# 17:23:50 INFO      trial values: 41.786,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=910037;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=862151;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.786,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=744312;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=970263;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70114,-21.689,40.423,61.243,-22.471 ->    ]8;id=998923;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=725494;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=67349;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=523523;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.651,61.243,-22.471 ->    ]8;id=906264;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=816673;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3713.107
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=904934;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=744547;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=98904;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=335983;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70114,-21.689,40.423,61.243,-22.471 ->    ]8;id=262228;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=989385;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70114,-21.689,40.651,61.243,-22.471 ->    ]8;id=174120;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=85716;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3713.106
#          INFO      trial values: 41.783,60.337,0.70114,-21.689,40.423,61.243,-22.471 ->    ]8;id=549839;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=804806;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70114,-21.689,40.423,61.243,-22.471 ->    ]8;id=761765;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=101703;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.651,61.243,-22.471 ->    ]8;id=105430;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=296764;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3713.107
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=305796;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=974792;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=686429;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=523696;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.651,61.243,-22.471 ->    ]8;id=815984;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=727026;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3713.106
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.651,61.243,-22.471 ->    ]8;id=548229;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=366341;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3713.107
#          INFO      trial values: 41.783,60.337,0.70099,-21.689,40.423,61.243,-22.471 ->    ]8;id=384263;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=46900;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1010\1010]8;;\
#                   logL = -3712.199
# Best fit values:
#                                                  result             unit
# parameter
# ext1.Gaussian_on_sphere.lon0       (4.18 +/- 0.04) x 10              deg
# ext1.Gaussian_on_sphere.lat0     (6.034 +/- 0.016) x 10              deg
# ext1.Gaussian_on_sphere.sigma     (7.0 +/- 1.8) x 10^-1              deg
# ext1.spectrum.main.Powerlaw.K  (2.0 -0.5 +0.6) x 10^-22  1 / (cm2 keV s)
# pt1.position.ra                  (4.042 +/- 0.019) x 10              deg
# pt1.position.dec                 (6.124 +/- 0.004) x 10              deg
# pt1.spectrum.main.Powerlaw.K   (3.4 -1.1 +1.5) x 10^-23  1 / (cm2 keV s)
# Correlation matrix:
#  1.00  0.02 -0.58 -0.52 -0.21 -0.07  0.41
#  0.02  1.00 -0.05  0.03 -0.03  0.02 -0.26
# -0.58 -0.05  1.00  0.84  0.22  0.03 -0.41
# -0.52  0.03  0.84  1.00  0.18  0.05 -0.47
# -0.21 -0.03  0.22  0.18  1.00  0.19 -0.26
# -0.07  0.02  0.03  0.05  0.19  1.00 -0.08
#  0.41 -0.26 -0.41 -0.47 -0.26 -0.08  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# WCDA        3712.198907
# total       3712.198907
# Values of statistical measures:
#      statistical measures
# AIC           7438.399978
# BIC           7500.377071
# Smoothing planes:   0%|          | 0/5 [00:00<?, ?it/s]
# 17:23:57 INFO      set the minimizer to minuit                                             ]8;id=76624;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=694563;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=130308;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=419957;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
# 17:24:18 INFO      Considering 7 dec bins for extended source ext1                  ]8;id=833411;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=615411;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#70\70]8;;\
#          INFO      Central bin is bin at Declination = 60.337                       ]8;id=838174;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=740182;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#79\79]8;;\
#          INFO      Considering 7 dec bins for extended source ext1                  ]8;id=755868;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=283354;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#70\70]8;;\
#          INFO      Central bin is bin at Declination = 60.337                       ]8;id=538586;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=998788;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#79\79]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=580046;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=482905;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
#          INFO      set the minimizer to minuit                                             ]8;id=361519;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=323956;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
# 17:24:19 INFO      Considering 7 dec bins for extended source ext1                  ]8;id=411344;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=965774;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#70\70]8;;\
#          INFO      Central bin is bin at Declination = 60.337                       ]8;id=382060;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py\convolved_extended_source.py]8;;\:]8;id=703981;file:///home/lhaaso/caowy/.mylib/miniconda/miniconda3/envs/3ML/lib/python3.9/site-packages/WCDA_hal/convolved_source/convolved_extended_source.py#79\79]8;;\

# %%
result[3]

# %%
plt.figure() #constrained_layout=True

ax1=plt.subplot(3, 1, 2)
plt.errorbar([aa[0] for aa in result],[bb[1][2][0] for bb in result],yerr=[[abs(cc[1][2][1]) for cc in result],[abs(dd[1][2][2]) for dd in result]],fmt='bo-',label="Ext1",elinewidth=2,capsize=4)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.grid()
# plt.xlabel("Nhit_bin")
plt.ylabel("Sigma[$^\circ$]")
plt.legend()

ax2=plt.subplot(3, 1, 1, sharex=ax1, sharey=ax1)
plt.errorbar([aa[0] for aa in result],[bb[1][6][0] for bb in result],yerr=[[abs(cc[1][6][1]) for cc in result],[abs(dd[1][6][2]) for dd in result]],fmt='go-',label="W43",elinewidth=2,capsize=4)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.grid()
# plt.xlabel("Nhit_bin")
plt.title("sigma")
plt.ylabel("Sigma[$^\circ$]")
plt.legend()

plt.subplot(3, 1, 3, sharex=ax1, sharey=ax1)
plt.errorbar([aa[0] for aa in result],[bb[1][10][0] for bb in result],yerr=[[abs(cc[1][10][1]) for cc in result],[abs(dd[1][10][2]) for dd in result]],fmt='o-',color="orange",label="Ext3",elinewidth=2,capsize=4)
plt.grid()
plt.xlabel("Nhit_bin")
plt.ylabel("Sigma[$^\circ$]")
plt.legend()
plt.savefig('result_sigma.jpg',dpi=300)
plt.show()

# %%
plt.figure() #constrained_layout=True

ax1=plt.subplot(3, 1, 2)
plt.errorbar([aa[0] for aa in result],[bb[1][3][0] for bb in result],yerr=[[abs(cc[1][3][1]) for cc in result],[abs(dd[1][3][2]) for dd in result]],fmt='bo-',label="Ext1",elinewidth=2,capsize=4)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.grid()
# plt.xlabel("Nhit_bin")
plt.ylabel("$1 / (cm^2 keV s)$")
plt.legend()

ax2=plt.subplot(3, 1, 1, sharex=ax1, sharey=ax1)
plt.errorbar([aa[0] for aa in result],[bb[1][7][0] for bb in result],yerr=[[abs(cc[1][7][1]) for cc in result],[abs(dd[1][7][2]) for dd in result]],fmt='go-',label="W43",elinewidth=2,capsize=4)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.grid()
plt.title("Normalization")
# plt.xlabel("Nhit_bin")
plt.ylabel("$1 / (cm^2 keV s)$")
plt.legend()

plt.subplot(3, 1, 3, sharex=ax1, sharey=ax1)
plt.errorbar([aa[0] for aa in result],[bb[1][11][0] for bb in result],yerr=[[abs(cc[1][11][1]) for cc in result],[abs(dd[1][11][2]) for dd in result]],fmt='o-',color="orange",label="Ext3",elinewidth=2,capsize=4)
plt.grid()
plt.xlabel("Nhit_bin")
plt.ylabel("$1 / (cm^2 keV s)$")
plt.legend()
plt.savefig('result_Normalization.jpg',dpi=300)
plt.show()

# %%
# result
fysize=4
figsize = (fysize+2, fysize+2.75)
plt.figure(figsize=figsize)
for i in trange(len(result), desc="progressive"):
    # if (result[i][1] == []):
    #     continue
    plt.errorbar(result[i][1][0][0],result[i][1][1][0],xerr=[[abs(result[i][1][0][1])],[abs(result[i][1][0][2])]],yerr=[[abs(result[i][1][1][1])],[abs(result[i][1][1][2])]],fmt='bo-')
    plt.text(result[i][1][0][0], result[i][1][1][0], result[i][0], fontsize=5, color = "r", style = "italic", weight = "bold", verticalalignment='center', horizontalalignment='center')
    plt.errorbar(result[i][1][4][0],result[i][1][5][0],xerr=[[abs(result[i][1][4][1])],[abs(result[i][1][4][2])]],yerr=[[abs(result[i][1][5][1])],[abs(result[i][1][5][2])]],fmt='go-')
    plt.text(result[i][1][4][0], result[i][1][5][0], result[i][0], fontsize=5, color = "r", style = "italic", weight = "bold", verticalalignment='center', horizontalalignment='center')
    plt.errorbar(result[i][1][8][0],result[i][1][9][0],xerr=[[abs(result[i][1][8][1])],[abs(result[i][1][8][2])]],yerr=[[abs(result[i][1][9][1])],[abs(result[i][1][9][2])]],fmt='o-',color="orange")
    plt.text(result[i][1][8][0], result[i][1][9][0], result[i][0], fontsize=5, color = "r", style = "italic", weight = "bold", verticalalignment='center', horizontalalignment='center')
plt.xlim(282.12-2.5,282.12+2.5)
plt.ylim(-1.89-2.5,-1.89+2.5)
plt.xlabel("Ra[$^\circ$]")
plt.ylabel("Dec[$^\circ$]")
plt.grid()
plt.gca().invert_xaxis()
plt.title("W43")
plt.savefig('./result_position.jpg',dpi=300)
plt.show()

# %% [markdown]
# ### 单独运行每一个bin拟合

# %%
time1 = strftime("%m-%d-%H", localtime())
os.system('mkdir ./%s/'%time1)
a=[]
activate_progress_bars()
# for i in trange(10, desc="progressive"):
#     pass
i=12
# for i in trange(13, desc="progressive"):
ii = str(i)
try:
    WCDA.set_active_measurements(i,i)
    datalist = DataList(WCDA)
    # jl_0 = JointLikelihood(lm0, datalist, verbose=True)
    # lll0=WCDA.get_log_like()
    jl = JointLikelihood(lm, datalist, verbose=True)
    jl.set_minimizer("minuit")
    param_df, like_df = jl.fit()
    results=jl.results
    fig = WCDA.display_fit(smoothing_kernel_sigma=0.25, display_colorbar=True)
    fig.savefig("./%s/fit_result_%i.pdf"%(time1,i))

    TS1 = jl.compute_TS("ext1",like_df).values[0][2]
    # TS2 = jl.compute_TS("ext2",like_df).values[0][2]
    # TS3 = jl.compute_TS("ext3",like_df).values[0][2]
    lll=WCDA.get_log_like()
    TS_all=2*lll
    a.append([i,TS1,TS_all,lll])
    #for bid in ("0"):
    pixid=roi.active_pixels(1024)
    WCDA.set_active_measurements(i,i)
    active_bin=WCDA._maptree._analysis_bins[ii]
    obs_raw=active_bin.observation_map.as_partial()
    bkg_raw=active_bin.background_map.as_partial()
    ex1=WCDA._get_expectation(active_bin,ii,0,1)
    # ex2=WCDA._get_expectation(active_bin,ii,0,2)
    # ex3=WCDA._get_expectation(active_bin,ii,0,3)
    nombre=['all']
    # if(ii==0):
    mode="recreate"
    # else:
        # mode="update"

    freepars = []
    fixedpars = []
    mat=param_df.as_matrix()
    for ipar in range (0,len(param_df.index)):
        freepars.append("%-35s %3.6g %3.2g +%3.2g (%3.2g) %s" % (param_df.index[ipar],mat[ipar][0],mat[ipar][1],mat[ipar][2],mat[ipar][3],mat[ipar][4]))
    for p in lm.parameters:
        par = lm.parameters[p]
        #     if par.free:
            #        freepars.append("%-45s %35.6g %s" % (p, par.value, par._unit))
        if par.fix:
            fixedpars.append("%-45s %35.6g %s" % (p, par.value, par._unit))
    with open("./%s/output_fit_%s.txt"%(time1,time1), "a+") as f:
        f.write("\n#################################%i\nBin%d\n"%(i,i))
        f.write("Test statistic: %g\n" % TS_all)
        f.write("EXT1:"+ str(TS1) + "\r\n")
        f.write("\nFree parameters:\n")
        for l in freepars:
            f.write("%s\n" % l)
        f.write("\nFixed parameters:\n")
        for l in fixedpars:
            f.write("%s\n" % l)

    for name in nombre:
        if (name=='all'):
            model=ex1
        # elif(name=='W43'):
        #     model=ex3-ex2+ex1
        neof=ROOT.TFile.Open(("./%s/result_%s_nhit%i.root"%(time1,name,i)),mode)
        f0=ROOT.TFile.Open("/eos/user/l/luoyu/wcda_skysurvey2/20210305_20220205_0h/20210305_20220205_pinc_new3.root",'read')
        #neof=neof=ROOT.TFile.Open('/eos/user/z/zhanghongfei/geminga/geminga_linked_res_20220308_13.root',mode)
        n10=neof.mkdir('nHit%02d'%i,'nHit%02d'%i)
        toFill=np.zeros(1,dtype=float)
        toFill_d=np.zeros(1,dtype=float)
        toFill_m=np.zeros(1,dtype=float)
        tree=ROOT.TTree('bkg_model','bkg_model')
        tree1=ROOT.TTree('data','data')
        tree2=ROOT.TTree('bkg','bkg')
        tree.SetDirectory(n10)
        tree.SetEntries(hp.nside2npix(1024))
        tree1.SetDirectory(n10)
        tree1.SetEntries(hp.nside2npix(1024))
        tree2.SetDirectory(n10)
        tree2.SetEntries(hp.nside2npix(1024))
        newb=tree.Branch("count",toFill,"count/D")
        b_d=tree1.Branch("count",toFill_d,"count/D")
        b_d2=tree2.Branch("count",toFill_m,"count/D")
        tdata=f0.Get("nHit%02d"%i).data
        tbkg=f0.Get("nHit%02d"%i).bkg
        for idx in range(hp.nside2npix(1024)):
                if(idx%1000000==0): print(idx)
                if(idx%1==0):
                    tree.GetEntry(idx)
                    tree1.GetEntry(idx)
                    tdata.GetEntry(idx)
                    tbkg.GetEntry(idx)
                    toFill_d[0]=tdata.count
                    b_d.Fill()
                    toFill_m[0]=tbkg.count
                    b_d2.Fill()
                    if idx in pixid:
                        roiid=np.argwhere(pixid==idx)[0][0]
                        toFill[0]=tbkg.count+model[roiid]
                        newb.Fill()#count=tbkg.count+model[roiid]
                    else:
                        toFill[0]=tbkg.count#+model[roiid]
                        newb.Fill()

        neof.Write("",ROOT.TFile.kOverwrite)
        neof.Close()
        f0.Close()
except Exception as e:
    with open("./%s/output_fit_%s.txt"%(time1,time1), "a+") as f:
        f.write("\n#################################%i\nBin%d ERR!!!\n"%(i,i))
        f.write(str(e.args))
        f.write("=========")
        f.write(traceback.format_exc())
    pass
print(a)

# %%
param_df

# %%
print(TS1,TS2,TS3,lll)
